# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# plt.figure(figsize=(30,12))
plt.rcParams['figure.figsize'] = [30,12]

# %%
def date_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[2]
    if date[1]=="02":
        return "February"+date[2]
    if date[1]=="03":
        return "March"+date[2]
    if date[1]=="04":
        return "April"+date[2]
    if date[1]=="05":
        return "May"+date[2]
    if date[1]=="06":
        return "June"+date[2]
    if date[1]=="07":
        return "July"+date[2]
    if date[1]=="08":
        return "August"+date[2]
    if date[1]=="09":
        return "September"+date[2]
    if date[1]=="10":
        return "October"+date[2]
    if date[1]=="11":
        return "November"+date[2]
    if date[1]=="12":
        return "December"+date[2]

# %%
def get_year(date):
    date=date.split("-")
    return date[2]

# %%
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
def bar_graph(categories,cat_val,xlabel,ylabel,title=""):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8)
    plt.title(title)
    plt.show()

# %%
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")

# %%
import datetime
import calendar
 
def findDay(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

# %%
def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17

# %%
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()

# %%
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1

# %%
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)

# %% [markdown]
# # PART-1: VARIANTS,COVID-WAVES AND ITS POTENTIAL CAUSES:

# %%
case_info=pd.read_csv("dl_case_info.csv")
case_info.drop(["Unnamed: 0"],axis="columns",inplace=True)
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case   month       day
# 0             2113.0    62.0          86.0  Jun-20   Tuesday
# ...

# %%
positive=case_info["cases_positive"].copy()
recovered=case_info["cases_recovered"].copy()

# %%
positive.head()
# Out:
# 0    2199.0
# 1    2084.0
# 2    2889.0
# 3    2948.0
# 4    3460.0
# Name: cases_positive, dtype: float64

# %%
positive.dropna(inplace=True)
recovered.dropna(inplace=True)

# %%
case_info["rise_in_case"]=""
case_info["rise_in_case"]=positive-recovered
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case   month       day
# 0             2113.0    62.0          86.0  Jun-20   Tuesday
# ...

# %%
case_info["month"]=""
case_info["month"]=case_info["date"].copy()
case_info["month"]=case_info["month"].apply(lambda x:date_month(x))
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case         month       day
# 0             2113.0    62.0          86.0      June2020   Tuesday
# ...

# %%
case_info["year"]=case_info["date"].copy()
case_info["year"]=case_info["year"].apply(lambda x:get_year(x))
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case         month       day  year
# 0             2113.0    62.0          86.0      June2020   Tuesday  2020
# ...

# %% [markdown]
# GATHERING INFO ABOUT CASES IN THE CITY

# %%
case_info.describe()
# Out:
#        cases_positive  tests_conducted  positivity_rate  cases_recovered  \
# count      509.000000       451.000000       451.000000       509.000000
# mean      2272.587426     64095.964523         3.532949      2320.119843
# std       4541.717247     12864.812036         6.611062      4392.821165
# min         15.000000     22603.000000         0.030000         1.000000
# 25%         54.000000     56573.000000         0.080000        62.000000
# 50%        407.000000     63313.000000         0.360000       423.000000
# 75%       2780.000000     72835.500000         5.235000      2975.000000
# max      27047.000000    114288.000000        36.240000     27421.000000
#
#            deaths  rise_in_case
# count  509.000000    509.000000
# mean    38.907662    -47.532417
# std     76.541182   1247.908102
# min      0.000000  -6394.000000
# 25%      1.000000   -177.000000
# 50%      8.000000     -8.000000
# 75%     39.000000     70.000000
# max    412.000000   6560.000000

# %%
case_info["month"].unique()
# Out:
# array(['June2020', 'July2020', 'August2020', 'September2020',
#        'October2020', 'November2020', 'December2020', 'January2021',
#        'February2021', 'March2021', 'April2021', 'May2021', 'June2021',
#        'July2021', 'August2021', 'September2021', 'October2021',
#        'November2021', 'December2021', 'January2022'], dtype=object)

# %% [markdown]
# DIVIDING THE DATASET INTO TWO SUBCATOGRIES
#
# 1. days where cases where increasing
# 2. days where cases where decreasing

# %%
increase=case_info[case_info["rise_in_case"]>0]
decrease=case_info[case_info["rise_in_case"]<0]
increase
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# 5    25-06-2020          3390.0              NaN              NaN
# 6    24-06-2020          3788.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case         month        day  year
# 0             2113.0    62.0          86.0      June2020    Tuesday  2020
# ...

# %% [markdown]
# NUMBER OF DAYS WHERE DELHI WITNESSED RISE IN CASE

# %%
print("NUMBER OF DAYS WHERE DELHI WITNESSED RISE IN CASE: ",len(increase["date"].unique()))
# Out:
# NUMBER OF DAYS WHERE DELHI WITNESSED RISE IN CASE:  221

# %%
increase["month"].unique()
# Out:
# array(['June2020', 'July2020', 'August2020', 'September2020',
#        'October2020', 'November2020', 'January2021', 'February2021',
#        'March2021', 'April2021', 'May2021', 'July2021', 'August2021',
#        'September2021', 'October2021', 'November2021', 'December2021',
#        'January2022'], dtype=object)

# %%
decrease
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 8    22-06-2020          2909.0              NaN              NaN
# 10   20-06-2020          3630.0              NaN              NaN
# 12   18-06-2020          2877.0              NaN              NaN
# ..          ...             ...              ...              ...
# 549  09-12-2021            55.0          59890.0             0.09
# 550  10-12-2021            41.0          59763.0             0.07
# 553  13-12-2021            30.0          46169.0             0.06
# 557  17-12-2021            69.0          57298.0             0.12
# 560  20-12-2021            91.0          46193.0             0.20
#
#      cases_recovered  deaths  rise_in_case         month       day  year
# 1             3628.0    57.0       -1544.0      June2020    Monday  2020
# ...

# %% [markdown]
# ANALYSIS WHEN CASES WERE INCREASING

# %%
df=increase.drop(["positivity_rate"],axis="columns").groupby(["month"],dropna=True).sum()
df
# Out:
#                cases_positive  tests_conducted  cases_recovered  deaths  \
# month
# April2021            329243.0        1960639.0         264655.0  3416.0
# August2020            12852.0              0.0          10695.0   153.0
# August2021              582.0         766832.0            401.0    17.0
# December2021           6644.0        1306089.0           2441.0     8.0
# February2021           2079.0         719659.0           1664.0    20.0
# January2021             430.0         130434.0            341.0    16.0
# January2022           15490.0         273236.0           5005.0     6.0
# July2020               5170.0              0.0           3593.0   136.0
# July2021                656.0         702423.0            507.0    24.0
# June2020              22732.0              0.0          16531.0   450.0
# March2021             21515.0        2021804.0          13274.0   105.0
# May2021               60745.0         233738.0          57082.0   990.0
# ...

# %%
df1=increase.groupby(["month"],dropna=True).mean()
df["positivity_rate"]=df1["positivity_rate"].copy()
df1
# Out:
#                cases_positive  tests_conducted  positivity_rate  \
# month
# April2021        14314.913043     85245.173913        17.566957
# August2020        1168.363636              NaN              NaN
# August2021          52.909091     69712.000000         0.076364
# December2021       302.000000     59367.681818         0.460455
# February2021       173.250000     59971.583333         0.290833
# January2021        215.000000     65217.000000         0.330000
# January2022       3872.500000     68309.000000         5.765000
# July2020          1723.333333              NaN              NaN
# July2021            65.600000     70242.300000         0.092000
# June2020          3247.428571              NaN              NaN
# March2021          768.392857     72207.285714         1.022857
# May2021          20248.333333     77912.666667        26.006667
# November2020      6829.555556     55344.333333        12.428889
# ...

# %%
df1["Index"]=df1.index.values.copy()
df1["Index"]=df1["Index"].apply(lambda x:set_index(x))
df1.sort_values(["Index"],inplace=True)

# %% [markdown]
# DESCRIPTION: The graph below is showing monthly Average rise in cases

# %%
bar_graph(df1.index.values,df1["rise_in_case"],"Months","Number of cases","Average rise in Cases perday")

# %%
plt.plot(df1.index.values,df1["rise_in_case"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# RELATION AND ASSOCIATION AMONG DIFFERENT PARAMETERS

# %%
print(linear_correlation(increase["cases_recovered"],increase["rise_in_case"]))
print(linear_correlation(increase["cases_recovered"],increase["deaths"]))
print(linear_correlation(increase["cases_positive"],increase["deaths"]))
# Out:
# 0.5351043678666627
# 0.9590853447552926
# 0.9374992319814972

# %% [markdown]
# CALCULATING: number of deaths registered per-day for every one percent average postivity rate

# %%
# TOTAL DEATHS REGISTERED ON ONE-PERCENTAGE INCREASE OF POSITIVE CASES
d1=pd.DataFrame()
d1["total_deaths"]=""
d1["total_deaths"]=df["deaths"].copy()
d1["postitvity_rate"]=df1["positivity_rate"].copy()

# %%
d1=d1.query("postitvity_rate>0").copy()
d1
d1["per_percentage"]=d1["total_deaths"]/d1["postitvity_rate"]
d1
# Out:
#                total_deaths  postitvity_rate  per_percentage
# month
# April2021            3416.0        17.566957      194.455994
# August2021             17.0         0.076364      222.619048
# December2021            8.0         0.460455       17.374136
# February2021           20.0         0.290833       68.767908
# January2021            16.0         0.330000       48.484848
# January2022             6.0         5.765000        1.040763
# July2021               24.0         0.092000      260.869565
# March2021             105.0         1.022857      102.653631
# May2021               990.0        26.006667       38.067162
# November2020         1579.0        12.428889      127.042732
# November2021            2.0         0.092000       21.739130
# October2020           702.0         7.241579       96.940185
# October2021             2.0         0.063077       31.707317
# September2020         352.0         6.844000       51.431911
# ...

# %%
d1["per_percentage_per_day"]=d1["per_percentage"]/30
d1
# Out:
#                total_deaths  postitvity_rate  per_percentage  \
# month
# April2021            3416.0        17.566957      194.455994
# August2021             17.0         0.076364      222.619048
# December2021            8.0         0.460455       17.374136
# February2021           20.0         0.290833       68.767908
# January2021            16.0         0.330000       48.484848
# January2022             6.0         5.765000        1.040763
# July2021               24.0         0.092000      260.869565
# March2021             105.0         1.022857      102.653631
# May2021               990.0        26.006667       38.067162
# November2020         1579.0        12.428889      127.042732
# November2021            2.0         0.092000       21.739130
# October2020           702.0         7.241579       96.940185
# October2021             2.0         0.063077       31.707317
# September2020         352.0         6.844000       51.431911
# ...

# %% [markdown]
# DESCRIPTION: The below graph is showing monthly data of number of deaths registered per-day for every one percent average postivity rate

# %%
d1["Index"]=d1.index.values.copy()
d1["Index"]=d1["Index"].apply(lambda x:set_index(x))
d1.sort_values(["Index"],inplace=True)

# %%
bar_graph(d1.index.values,d1["per_percentage_per_day"],"Months","Number of deaths","Per percentage deaths in each day (grouped by months)")

# %% [markdown]
# DESCRIPTION: The below graph is showing monthly data of number of deaths registered in a month for every one percent average postivity rate

# %%
bar_graph(d1.index.values,d1["per_percentage"],"Months","Number of deaths","Per percentage deaths in whole month (cumulative)")

# %%
plt.plot(d1.index.values,d1["per_percentage"].values,color='red', marker='o', linestyle='-')

# %% [markdown]
# DECREASE STARTS HERE--------

# %%
decrease
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 8    22-06-2020          2909.0              NaN              NaN
# 10   20-06-2020          3630.0              NaN              NaN
# 12   18-06-2020          2877.0              NaN              NaN
# ..          ...             ...              ...              ...
# 549  09-12-2021            55.0          59890.0             0.09
# 550  10-12-2021            41.0          59763.0             0.07
# 553  13-12-2021            30.0          46169.0             0.06
# 557  17-12-2021            69.0          57298.0             0.12
# 560  20-12-2021            91.0          46193.0             0.20
#
#      cases_recovered  deaths  rise_in_case         month       day  year
# 1             3628.0    57.0       -1544.0      June2020    Monday  2020
# ...

# %% [markdown]
# DECREASE ENDS HERE--------

# %%
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case         month       day  year
# 0             2113.0    62.0          86.0      June2020   Tuesday  2020
# ...

# %%
case_info["day"]=case_info["date"].copy()
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case         month         day  year
# 0             2113.0    62.0          86.0      June2020  30-06-2020  2020
# ...

# %%
case_info["day"]=case_info["day"].apply(lambda x:findDay(x))
case_info
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 0    30-06-2020          2199.0              NaN              NaN
# 1    29-06-2020          2084.0              NaN              NaN
# 2    28-06-2020          2889.0              NaN              NaN
# 3    27-06-2020          2948.0              NaN              NaN
# 4    26-06-2020          3460.0              NaN              NaN
# ..          ...             ...              ...              ...
# 571  31-12-2021          1796.0          73590.0             2.44
# 572  01-01-2022          2716.0          74622.0             3.64
# 573  02-01-2022          3194.0          69650.0             4.59
# 574  03-01-2022          4099.0          63477.0             6.46
# 575  04-01-2022          5481.0          65487.0             8.37
#
#      cases_recovered  deaths  rise_in_case         month       day  year
# 0             2113.0    62.0          86.0      June2020   Tuesday  2020
# ...

# %%
csum=case_info.drop(["positivity_rate"],axis="columns").groupby(["day"]).sum()
csum
# Out:
#            cases_positive  tests_conducted  cases_recovered  deaths  \
# day
# Friday           169237.0        4434172.0         172171.0  2884.0
# Monday           118668.0        3212937.0         149303.0  2735.0
# Saturday         177156.0        4513766.0         199729.0  3185.0
# Sunday           181089.0        3992360.0         179545.0  2799.0
# Thursday         162773.0        4339701.0         154605.0  2482.0
# Tuesday          165211.0        4090609.0         142566.0  2863.0
# Wednesday        182613.0        4323735.0         183022.0  2856.0
#
#            rise_in_case
# day
# Friday          -2934.0
# Monday         -30635.0
# Saturday       -22573.0
# Sunday           1544.0
# Thursday         8168.0
# Tuesday         22645.0
# Wednesday        -409.0

# %% [markdown]
# DESCRIPTION:The graph below shows the total increase or decrease in cases day-wise in a week.
#     The negative bar graph shows that there was a decrease in cases in those days cumulative.

# %%
bar_graph(csum.index.values,csum["rise_in_case"].values,"Days","rise_in_case","AVERAGE INCREASE IN CASES DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION:The graph below shows the total test-conducted day-wise in a week.

# %%
bar_graph(csum.index.values,csum["tests_conducted"].values,"Days","Number of Tests Conducted","AVERAGE INCREASE IN CASES DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION:The graph below shows the total positive-cases day-wise in a week.

# %%
bar_graph(csum.index.values,csum["cases_positive"].values,"Days","Number of Positive Cases","TOTAL NUMBER OF POSITIVE CASES")

# %% [markdown]
# DESCRIPTION:The graph below shows the total cases recovered day-wise.

# %%
bar_graph(csum.index.values,csum["cases_recovered"].values,"Days","Number of Cases Recovered","TOTAL NUMBER CASES RECOVERED DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION:The graph below shows the total deaths registered day-wise.

# %%
bar_graph(csum.index.values,csum["deaths"].values,"Days","Number of Deaths Registered","TOTAL NUMBER DEATHS REGISTERED DAY-WISE IN A WEEK")

# %%
cmean=case_info.groupby(["day"]).mean()
cmean
# Out:
#            cases_positive  tests_conducted  positivity_rate  cases_recovered  \
# day
# Friday        2350.513889     68218.030769         3.380615      2391.263889
# Monday        1625.589041     50202.140625         3.285625      2045.246575
# Saturday      2300.727273     66378.911765         3.591471      2593.883117
# Sunday        2550.549296     64392.903226         3.994032      2528.802817
# Thursday      2260.736111     67807.828125         3.335938      2147.291667
# Tuesday       2294.597222     63915.765625         3.479375      1980.083333
# Wednesday     2536.291667     67558.359375         3.676719      2541.972222
#
#               deaths  rise_in_case
# day
# Friday     40.055556    -40.750000
# Monday     37.465753   -419.657534
# Saturday   41.363636   -293.155844
# Sunday     39.422535     21.746479
# Thursday   34.472222    113.444444
# Tuesday    39.763889    314.513889
# Wednesday  39.666667     -5.680556

# %% [markdown]
# DESCRIPTION:The graph below shows the average increase or decrease in cases day-wise.
#     The negative bar graph shows that there was a decrease in cases in those days cumulative.

# %%
bar_graph(cmean.index.values,cmean["rise_in_case"].values,"Days","rise_in_case","AVERAGE INCREASE IN CASES DAY-WISE IN A WEEK")

# %% [markdown]
# NOW BELOW IS THE SCENARIO WHERE NUMBER OF POSITIVE CASES WERE ONLY INCREASING

# %%
increase=case_info[case_info["rise_in_case"]>0]
decrease=case_info[case_info["rise_in_case"]<0]

# %%
increase["day"]=increase["date"].copy()
decrease["day"]=decrease["date"].copy()
# Out:
# C:\Users\anura\AppData\Local\Temp/ipykernel_5840/3066118202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   increase["day"]=increase["date"].copy()
# C:\Users\anura\AppData\Local\Temp/ipykernel_5840/3066118202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   decrease["day"]=decrease["date"].copy()

# %%
increase["day"]=increase["day"].apply(lambda x:findDay(x))
decrease["day"]=decrease["day"].apply(lambda x:findDay(x))
# Out:
# C:\Users\anura\AppData\Local\Temp/ipykernel_5840/1897922527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   increase["day"]=increase["day"].apply(lambda x:findDay(x))
# C:\Users\anura\AppData\Local\Temp/ipykernel_5840/1897922527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   decrease["day"]=decrease["day"].apply(lambda x:findDay(x))

# %%
d11=increase.drop(["positivity_rate"],axis="columns").groupby(["day"]).sum()
d11
# Out:
#            cases_positive  tests_conducted  cases_recovered  deaths  \
# day
# Friday           120528.0        2020527.0         103678.0  1463.0
# Monday            28997.0         711072.0          19863.0   273.0
# Saturday          81888.0        1606209.0          70090.0   885.0
# Sunday           110323.0        1540128.0          85836.0  1050.0
# Thursday         114985.0        2389175.0          88421.0  1127.0
# Tuesday          130511.0        2357951.0          92485.0  1614.0
# Wednesday        131971.0        2371133.0         113784.0  1570.0
#
#            rise_in_case
# day
# Friday          16850.0
# Monday           9134.0
# Saturday        11798.0
# Sunday          24487.0
# Thursday        26564.0
# Tuesday         38026.0
# Wednesday       18187.0

# %%
d12=increase.groupby(["day"]).mean()
d12
# Out:
#            cases_positive  tests_conducted  positivity_rate  cases_recovered  \
# day
# Friday        3652.363636     67350.900000         5.121333      3141.757576
# Monday        1933.133333     54697.846154         3.349231      1324.200000
# Saturday      2924.571429     64248.360000         4.822800      2503.214286
# Sunday        4243.192308     64172.000000         6.426250      3301.384615
# Thursday      2948.333333     66365.972222         4.497778      2267.205128
# Tuesday       3183.195122     63728.405405         4.813243      2255.731707
# Wednesday     3383.871795     67746.657143         4.861429      2917.538462
#
#               deaths  rise_in_case
# day
# Friday     44.333333    510.606061
# Monday     18.200000    608.933333
# Saturday   31.607143    421.357143
# Sunday     40.384615    941.807692
# Thursday   28.897436    681.128205
# Tuesday    39.365854    927.463415
# Wednesday  40.256410    466.333333

# %% [markdown]
# DESCRIPTION: The graph below shows average rise in cases day-wise in a week

# %%
bar_graph(d12.index.values,d12["rise_in_case"].values,"Days","rise_in_case","AVERAGE INCREASE IN CASES DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows sum total rise in cases day-wise in a week

# %%
bar_graph(d11.index.values,d11["rise_in_case"].values,"Days","rise_in_case","TOTAL INCREASE IN CASES (DAY-WISE) IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows average tests conducted day-wise in a week

# %%
bar_graph(d12.index.values,d12["tests_conducted"].values,"Days","Tests conducted","AVERAGE TEST CONDUCTED DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows average deaths registered day-wise in a week

# %%
bar_graph(d12.index.values,d12["deaths"].values,"Days","Number of Deaths","AVERAGE DEATHS REGISTERED DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows average number of cases recovered day-wise in a week

# %%
bar_graph(d12.index.values,d12["cases_recovered"].values,"Days","Number of Cases Recovered","AVERAGE NUMBER OF CASES RECOVERED DAY-WISE IN A WEEK")

# %% [markdown]
# NOW BELOW IS THE SCENARIO WHERE NUMBER OF POSITIVE CASES WERE ONLY DECREASING

# %%
d14=decrease.drop(["positivity_rate"],axis="columns").groupby(["day"]).sum()
d14
# Out:
#            cases_positive  tests_conducted  cases_recovered  deaths  \
# day
# Friday            48709.0        2413645.0          68493.0  1421.0
# Monday            89671.0        2501865.0         129440.0  2462.0
# Saturday          95236.0        2853308.0         129607.0  2300.0
# Sunday            70766.0        2452232.0          93709.0  1749.0
# Thursday          47788.0        1950526.0          66184.0  1355.0
# Tuesday           34700.0        1732658.0          50081.0  1249.0
# Wednesday         50642.0        1952602.0          69238.0  1286.0
#
#            rise_in_case
# day
# Friday         -19784.0
# Monday         -39769.0
# Saturday       -34371.0
# Sunday         -22943.0
# Thursday       -18396.0
# Tuesday        -15381.0
# Wednesday      -18596.0

# %%
d15=decrease.groupby(["day"]).mean()
d15
# Out:
#            cases_positive  tests_conducted  positivity_rate  cases_recovered  \
# day
# Friday        1248.948718     68961.285714         1.888571      1756.230769
# Monday        1546.051724     49056.176471         3.269412      2231.724138
# Saturday      1984.083333     67935.904762         2.942619      2700.145833
# Sunday        1572.577778     64532.421053         2.457895      2082.422222
# Thursday      1448.121212     69661.642857         1.842143      2005.575758
# Tuesday       1119.354839     64172.518519         1.651481      1615.516129
# Wednesday     1534.606061     67331.103448         2.246897      2098.121212
#
#               deaths  rise_in_case
# day
# Friday     36.435897   -507.282051
# Monday     42.448276   -685.672414
# Saturday   47.916667   -716.062500
# Sunday     38.866667   -509.844444
# Thursday   41.060606   -557.454545
# Tuesday    40.290323   -496.161290
# Wednesday  38.969697   -563.515152

# %% [markdown]
# DESCRIPTION: The graph below shows average number of cases decreased day-wise.

# %%
bar_graph(d15.index.values,d15["rise_in_case"].values,"Days","rise_in_case","AVERAGE DECREASE IN CASES DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows total number of cases decreased day-wise.

# %%
bar_graph(d14.index.values,d14["rise_in_case"].values,"Days","decrease_in_case","TOTAL DECREASE IN CASES (DAY-WISE) IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows average number of tests conducted day-wise.

# %%
bar_graph(d15.index.values,d15["tests_conducted"].values,"Days","Tests conducted","AVERAGE TEST CONDUCTED DAY-WISE IN A WEEK")

# %% [markdown]
# DESCRIPTION: The graph below shows average number of deaths registered day-wise.

# %%
bar_graph(d15.index.values,d15["deaths"].values,"Days","Number of Deaths","AVERAGE DEATHS REGISTERED DAY-WISE IN A WEEK")

# %% [markdown]
# COMPARISION BETWEEN INCREASING CASES DAYS VS DECREASING CASES DAYS

# %%
average_death_dec=d15["deaths"].values.sum()
average_death_inc=d12["deaths"].values.sum()

# %%
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    explode = (0,0.1)
    plt.pie(values,colors=["green","red"],labels=values,explode=explode,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()

# %% [markdown]
# DESCRIPTION: The graph below shows Average death during increasing days vs decreasing days

# %%
piechart(["Average Death during Increasing days","Average Death during Decreasing days"],[average_death_inc,average_death_dec],"Average death during increasing days vs decreasing days")

# %% [markdown]
# DESCRIPTION: The graph below shows Average Tests conducted during increasing days vs decreasing days

# %%
avg_test_inc=d12["tests_conducted"].values.sum()
avg_test_dec=d15["tests_conducted"].values.sum()
piechart(["Average Tests Conducted during Increasing days","Average Tests Conducted during Decreasing days"],[avg_test_inc,avg_test_dec],"Average Tests conducted during increasing days vs decreasing days")

# %% [markdown]
# HOSPITAL AND PATIENT MANAGEMENT

# %%
hosp_mgmt=pd.read_csv("DL_patient_mgmt.csv")
hosp_mgmt
# Out:
#            date  hospital_beds_total  hospital_beds_occupied  \
# 0    2020-06-30              13661.0                  5912.0
# 1    2020-06-29              13411.0                  5977.0
# 2    2020-06-28              13411.0                  6014.0
# 3    2020-06-27              13411.0                  6068.0
# 4    2020-06-26              13411.0                  6221.0
# ..          ...                  ...                     ...
# 523  2021-12-31               8943.0                   226.0
# 524  2022-01-01               8883.0                   247.0
# 525  2022-01-02               9024.0                   307.0
# 526  2022-01-03               9029.0                   420.0
# 527  2022-01-04               9042.0                   531.0
#
#      hospital_beds_vacant  covid_care_center_beds_total  \
# 0                  7749.0                        7869.0
# 1                  7434.0                        7869.0
# 2                  7397.0                        5909.0
# ...

# %%
plt.rcParams['figure.figsize'] = [30,12]

# %%
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1

# %%
hosp_mgmt["date"]=hosp_mgmt["date"].apply(lambda x:rearrange_date(x))
hosp_mgmt
# Out:
#            date  hospital_beds_total  hospital_beds_occupied  \
# 0    30-06-2020              13661.0                  5912.0
# 1    29-06-2020              13411.0                  5977.0
# 2    28-06-2020              13411.0                  6014.0
# 3    27-06-2020              13411.0                  6068.0
# 4    26-06-2020              13411.0                  6221.0
# ..          ...                  ...                     ...
# 523  31-12-2021               8943.0                   226.0
# 524  01-01-2022               8883.0                   247.0
# 525  02-01-2022               9024.0                   307.0
# 526  03-01-2022               9029.0                   420.0
# 527  04-01-2022               9042.0                   531.0
#
#      hospital_beds_vacant  covid_care_center_beds_total  \
# 0                  7749.0                        7869.0
# 1                  7434.0                        7869.0
# 2                  7397.0                        5909.0
# ...

# %%
dates=hosp_mgmt["date"].values
dates
# Out:
# array(['30-06-2020', '29-06-2020', '28-06-2020', '27-06-2020',
#        '26-06-2020', '25-06-2020', '24-06-2020', '23-06-2020',
#        '22-06-2020', '21-06-2020', '20-06-2020', '18-06-2020',
#        '01-07-2020', '02-07-2020', '03-07-2020', '04-07-2020',
#        '05-07-2020', '06-07-2020', '07-07-2020', '08-07-2020',
#        '09-07-2020', '11-07-2020', '12-07-2020', '13-07-2020',
#        '14-07-2020', '15-07-2020', '16-07-2020', '17-07-2020',
#        '18-07-2020', '19-07-2020', '20-07-2020', '21-07-2020',
#        '22-07-2020', '23-07-2020', '24-07-2020', '25-07-2020',
#        '26-07-2020', '27-07-2020', '28-07-2020', '29-07-2020',
#        '31-07-2020', '01-08-2020', '02-08-2020', '03-08-2020',
#        '04-08-2020', '05-08-2020', '06-08-2020', '07-08-2020',
#        '08-08-2020', '09-08-2020', '10-08-2020', '11-08-2020',
#        '12-08-2020', '13-08-2020', '14-08-2020', '15-08-2020',
#        '16-08-2020', '17-08-2020', '18-08-2020', '19-08-2020',
# ...

# %%
hosp_mgmt["cases_positive"]=""
hosp_mgmt['positivity_rate']=""
hosp_mgmt['cases_recovered']=""
hosp_mgmt['deaths']=""
hosp_mgmt['rise_in_case']=""

# %%
lis=["cases_positive",'positivity_rate','cases_recovered','deaths','rise_in_case']
hosp_mgmt
# Out:
#            date  hospital_beds_total  hospital_beds_occupied  \
# 0    30-06-2020              13661.0                  5912.0
# 1    29-06-2020              13411.0                  5977.0
# 2    28-06-2020              13411.0                  6014.0
# 3    27-06-2020              13411.0                  6068.0
# 4    26-06-2020              13411.0                  6221.0
# ..          ...                  ...                     ...
# 523  31-12-2021               8943.0                   226.0
# 524  01-01-2022               8883.0                   247.0
# 525  02-01-2022               9024.0                   307.0
# 526  03-01-2022               9029.0                   420.0
# 527  04-01-2022               9042.0                   531.0
#
#      hospital_beds_vacant  covid_care_center_beds_total  \
# 0                  7749.0                        7869.0
# 1                  7434.0                        7869.0
# 2                  7397.0                        5909.0
# ...

# %%
for i in dates:
    for j in lis:
        hosp_mgmt.loc[hosp_mgmt["date"]==i,j]=case_info.loc[case_info["date"]==i,j]
hosp_mgmt
# Out:
#            date  hospital_beds_total  hospital_beds_occupied  \
# 0    30-06-2020              13661.0                  5912.0
# 1    29-06-2020              13411.0                  5977.0
# 2    28-06-2020              13411.0                  6014.0
# 3    27-06-2020              13411.0                  6068.0
# 4    26-06-2020              13411.0                  6221.0
# ..          ...                  ...                     ...
# 523  31-12-2021               8943.0                   226.0
# 524  01-01-2022               8883.0                   247.0
# 525  02-01-2022               9024.0                   307.0
# 526  03-01-2022               9029.0                   420.0
# 527  04-01-2022               9042.0                   531.0
#
#      hospital_beds_vacant  covid_care_center_beds_total  \
# 0                  7749.0                        7869.0
# 1                  7434.0                        7869.0
# 2                  7397.0                        5909.0
# ...

# %%
hosp_mgmt["day"]=hosp_mgmt["date"].copy()
hosp_mgmt["day"]=hosp_mgmt["day"].apply(lambda x:findDay(x))
hosp_mgmt["month"]=hosp_mgmt["date"].copy()
hosp_mgmt["month"]=hosp_mgmt["month"].apply(lambda x:date_month(x))
# hosp_mgmt

# %% [markdown]
# Count of available data per month

# %%
hosp_mgmt.groupby(["month"]).count()
# Out:
#                date  hospital_beds_total  hospital_beds_occupied  \
# month
# April2021        24                   24                      24
# August2020       30                   30                      30
# August2021       30                   30                      30
# December2020     29                   26                      26
# December2021     31                   31                      31
# February2021     25                   25                      25
# January2021      30                   24                      24
# January2022       4                    4                       4
# July2020         29                   29                      29
# July2021         30                   30                      30
# June2020         12                   12                      12
# June2021         25                   25                      25
# March2021        30                   30                      30
# ...

# %%
sum1=hosp_mgmt.groupby(["month"]).sum()
# sum1

# %% [markdown]
# DESCRIPTION: The below graph shows the sum of beds occupied by patients in a month, the below data can be used to determine
#     the months during which there was more number of inflow of patients to different hospitals and can be used to cross-check tax collection in each month.

# %%
sum1["Index"]=sum1.index.values.copy()
sum1["Index"]=sum1["Index"].apply(lambda x:set_index(x))
sum1.sort_values(["Index"],inplace=True)

# %%
bar_graph(sum1.index.values,sum1["hospital_beds_occupied"].values,"Months","Total number of hospital beds used","Total number of hospital beds used per month")

# %% [markdown]
# DESCRIPTION: The below graph shows the sum of beds occupied by patients in a month, the below data can be used to determine
#     the months during which there were more number of inflow of patients to different covid care centres and can be used to cross check the sell of medicines.

# %%
bar_graph(sum1.index.values,sum1["covid_care_center_beds_occupied"].values,"Months","Total number of covid care center beds used","Total number of covid care center beds used")

# %% [markdown]
# NOTE: April 2021 is the month which shows highest deviation from average beds in the city, the total number of beds in the april month varied drastiacally in a single month.As there is so much deviation in the data, the median shows much more accurate data to measure central tendency.

# %%
# CHANGING APRIL2021's data from the table
# complete this before submitting.....

# %%
dfd=df.copy()
df
# Out:
#                cases_positive  tests_conducted  cases_recovered  deaths  \
# month
# April2021            329243.0        1960639.0         264655.0  3416.0
# August2020            12852.0              0.0          10695.0   153.0
# August2021              582.0         766832.0            401.0    17.0
# December2021           6644.0        1306089.0           2441.0     8.0
# February2021           2079.0         719659.0           1664.0    20.0
# January2021             430.0         130434.0            341.0    16.0
# January2022           15490.0         273236.0           5005.0     6.0
# July2020               5170.0              0.0           3593.0   136.0
# July2021                656.0         702423.0            507.0    24.0
# June2020              22732.0              0.0          16531.0   450.0
# March2021             21515.0        2021804.0          13274.0   105.0
# May2021               60745.0         233738.0          57082.0   990.0
# ...

# %% [markdown]
# DESCRIPTION: The table below shows total sum of all the columns on monthly basis.

# %%
dfd=pd.merge(dfd, sum1, left_index=True, right_index=True)
dfd["tests_conducted"]=dfd["tests_conducted"].apply(lambda x:"Nan" if x==0 else x)
dfd.dropna(inplace=True)
dfd
# Out:
#                cases_positive tests_conducted  cases_recovered  deaths  \
# month
# April2021            329243.0       1960639.0         264655.0  3416.0
# August2021              582.0        766832.0            401.0    17.0
# December2021           6644.0       1306089.0           2441.0     8.0
# February2021           2079.0        719659.0           1664.0    20.0
# January2021             430.0        130434.0            341.0    16.0
# January2022           15490.0        273236.0           5005.0     6.0
# July2021                656.0        702423.0            507.0    24.0
# March2021             21515.0       2021804.0          13274.0   105.0
# May2021               60745.0        233738.0          57082.0   990.0
# November2020         122932.0        996198.0         102361.0  1579.0
# November2021            431.0        477835.0            255.0     2.0
# October2020           76124.0       1053531.0          61460.0   702.0
# ...

# %%
dfd["Index"]=dfd.index.values.copy()
dfd["Index"]=dfd["Index"].apply(lambda x:set_index(x))
dfd.sort_values(["Index"],inplace=True)

# %%
dfd.columns
# Out:
# Index(['cases_positive', 'tests_conducted', 'cases_recovered', 'deaths',
#        'rise_in_case', 'positivity_rate', 'hospital_beds_total',
#        'hospital_beds_occupied', 'hospital_beds_vacant',
#        'covid_care_center_beds_total', 'covid_care_center_beds_occupied',
#        'covid_care_center_beds_vacant', 'covid_health_center_beds_total',
#        'covid_health_center_beds_occupied', 'covid_health_center_beds_vacant',
#        'home_isolation_count', 'Index'],
#       dtype='object')

# %% [markdown]
# DESCRIPTION: The graph below shows "total hospital bed available" V/S "total hospital bed occupied" V/S "number of people stayed in home isolation".

# %%
dfd[["hospital_beds_total","hospital_beds_occupied","home_isolation_count"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# DESCRIPTION: The below table shows average of all the fields (month-wise)

# %%
dfd[["cases_positive","tests_conducted"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %%
dfd["death_per_rate_positvity"]=dfd["deaths"]/dfd["positivity_rate"]

# %%
dfd[["positivity_rate","death_per_rate_positvity"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# Pearson Correlationship among different field is presented below

# %%
print(linear_correlation(dfd1["cases_positive"],dfd1["hospital_beds_total"]))
print(linear_correlation(dfd1["cases_positive"],dfd1["home_isolation_count"]))
print(linear_correlation(dfd1["rise_in_case"],dfd1["hospital_beds_total"]))
print(linear_correlation(dfd1["rise_in_case"],dfd1["covid_care_center_beds_total"]))
print(linear_correlation(dfd1["rise_in_case"],dfd1["covid_health_center_beds_total"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5840/52641695.py in <module>
# ----> 1 print(linear_correlation(dfd1["cases_positive"],dfd1["hospital_beds_total"]))
#       2 print(linear_correlation(dfd1["cases_positive"],dfd1["home_isolation_count"]))
#       3 print(linear_correlation(dfd1["rise_in_case"],dfd1["hospital_beds_total"]))
#       4 print(linear_correlation(dfd1["rise_in_case"],dfd1["covid_care_center_beds_total"]))
#       5 print(linear_correlation(dfd1["rise_in_case"],dfd1["covid_health_center_beds_total"]))
#
# NameError: name 'dfd1' is not defined

# %%
# remove april mean data from the table and replace it with median data....

# %% [markdown]
# # ANALYSIS ON TESTING

# %%
twenty_21=case_info[case_info["year"]=="2021"]
twenty_21
# Out:
#            date  cases_positive  tests_conducted  positivity_rate  \
# 212  01-01-2021           585.0          80565.0             0.73
# 213  02-01-2021           494.0          67364.0             0.73
# 214  03-01-2021           424.0          68759.0             0.62
# 215  04-01-2021           384.0          50288.0             0.76
# 216  05-01-2021           442.0          79777.0             0.55
# ..          ...             ...              ...              ...
# 567  27-12-2021           331.0          48589.0             0.68
# 568  28-12-2021           496.0          55865.0             0.89
# 569  29-12-2021           923.0          71696.0             1.29
# 570  30-12-2021          1313.0          75953.0             1.73
# 571  31-12-2021          1796.0          73590.0             2.44
#
#      cases_recovered  deaths  rise_in_case         month        day  year
# 212            717.0    21.0        -132.0   January2021     Friday  2021
# ...

# %%
twenty_21.groupby(['day']).count()

# %% [markdown]
# Average rise in case in 2021

# %%
inc_21=twenty_21.loc[twenty_21["rise_in_case"]>0,"rise_in_case"]
inc_21.mean()

# %%
twenty_20_sum=twenty_20.groupby(["day"]).sum()
twenty_20_sum

# %%
twenty_20_mean=twenty_20.groupby(["day"]).mean()
twenty_20_mean.drop(["cases_positive","positivity_rate","cases_recovered"],axis="columns",inplace=True)
twenty_20_mean

# %%
twenty_21_sum=twenty_21.groupby(["day"]).sum()
twenty_21_sum

# %%
twenty_21_mean=twenty_21.groupby(["day"]).mean()
twenty_21_mean

# %%
combine = pd.merge(twenty_20_sum,twenty_21_sum,left_index=True, right_index=True)
combine

# %%
combine[["tests_conducted_x","tests_conducted_y"]].plot(kind="bar")

# %%
combine[["deaths_x","deaths_y"]].plot(kind="bar")

# %% [markdown]
# # VACCINES

# %%
vaccine=pd.read_csv("DL_vaccination.csv")
vaccine
# Out:
#            date  vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  \
# 0    2021-04-11         104862               91099             13763
# 1    2021-04-12          74397               68038              6359
# 2    2021-04-13          89065               73827             15238
# 3    2021-04-15          71030               58205             12825
# 4    2021-04-18          67448               54306             13142
# ..          ...            ...                 ...               ...
# 246  2021-12-31         170595               72639             97956
# 247  2022-01-01         124148               52767             71381
# 248  2022-01-02          83867               34922             48945
# 249  2022-01-03          23614                9167             14447
# 250  2022-01-04         185595               92928             92667
#
#      vax_cumulative  vax_cumulative_first_dose  vax_cumulative_sec_dose
# ...

# %%
vaccine.plot(x="date",y=["vax_first_dose_24h","vax_sec_dose_24h"])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
vaccine["date"]=vaccine["date"].apply(lambda x:rearrange_date(x))
vaccine["day"]=vaccine["date"].copy()
vaccine["month"]=vaccine["date"].copy()
vaccine["year"]=vaccine["date"].copy()

# %%
vaccine["day"]=vaccine["day"].apply(lambda x:findDay(x))
vaccine["month"]=vaccine["month"].apply(lambda x:date_month(x))
vaccine["year"]=vaccine["year"].apply(lambda x:get_year(x))
vaccine
# Out:
#            date  vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  \
# 0    11-04-2021         104862               91099             13763
# 1    12-04-2021          74397               68038              6359
# 2    13-04-2021          89065               73827             15238
# 3    15-04-2021          71030               58205             12825
# 4    18-04-2021          67448               54306             13142
# ..          ...            ...                 ...               ...
# 246  31-12-2021         170595               72639             97956
# 247  01-01-2022         124148               52767             71381
# 248  02-01-2022          83867               34922             48945
# 249  03-01-2022          23614                9167             14447
# 250  04-01-2022         185595               92928             92667
#
#      vax_cumulative  vax_cumulative_first_dose  vax_cumulative_sec_dose  \
# ...

# %% [markdown]
# GROUPING BY YEAR

# %% [markdown]
# Available data count per year available

# %%
vac_year_count=vaccine.groupby(["year"]).count()
vac_year_count
# Out:
#       date  vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  \
# year
# 2021   247            247                 247               247
# 2022     4              4                   4                 4
#
#       vax_cumulative  vax_cumulative_first_dose  vax_cumulative_sec_dose  day  \
# year
# 2021             247                        247                      247  247
# 2022               4                          4                        4    4
#
#       month
# year
# 2021    247
# 2022      4

# %%
vac_year=vaccine.groupby(["year"]).mean()
vac_year
# Out:
#       vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  vax_cumulative  \
# year
# 2021   93495.550607        51045.825911      42449.797571    1.371136e+07
# 2022  104306.000000        47446.000000      56860.000000    2.648586e+07
#
#       vax_cumulative_first_dose  vax_cumulative_sec_dose
# year
# 2021               9.154045e+06             4.557318e+06
# 2022               1.527644e+07             1.120942e+07

# %% [markdown]
# DESCRIPTION: The graph shows the average of first dose and second dose regsitered in 2021 and 2022 against average of cumulative vaccines registered in 2021 and 2022 respectively.
#     This graph shows that in 2022 percentage of people taking second dose inreased, that is the average second dose registered is bridging the gap between average number of first dose and average number of second dose. Which direcltyb implies that most people are going for second dose.

# %%
vac_year[["vax_cumulative","vax_cumulative_first_dose","vax_cumulative_sec_dose"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
vac_year_sum=vaccine.groupby(["year"]).sum()
vac_year_sum
# Out:
#       vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  vax_cumulative  \
# year
# 2021       23093401            12608319          10485100      3386706635
# 2022         417224              189784            227440       105943448
#
#       vax_cumulative_first_dose  vax_cumulative_sec_dose
# year
# 2021                 2261049167               1125657468
# 2022                   61105772                 44837676

# %% [markdown]
# DESCRIPTION: The graph showing the ratio of total cumulative vaccines registered V/S total cumulative first dose V/S total cumulative second dose

# %%
vac_year_sum[["vax_cumulative","vax_cumulative_first_dose","vax_cumulative_sec_dose"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# GROUPING MONTH WISE

# %%
vacc_month_mean=vaccine.groupby(["month"]).mean()
vacc_month_mean
# Out:
#                vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  \
# month
# April2021       64936.928571        48353.142857      16583.785714
# August2021     107872.833333        68719.266667      39153.566667
# December2021   116450.483871        42826.161290      73624.322581
# January2022    104306.000000        47446.000000      56860.000000
# July2021        67822.400000        41788.233333      26034.166667
# June2021        82268.560000        62079.840000      20188.720000
# May2021         71470.259259        53016.222222      18454.037037
# November2021    75263.766667        27579.600000      47684.766667
# October2021     88549.741935        33855.838710      54693.903226
# September2021  148761.931034        83730.551724      65031.379310
#
#                vax_cumulative  vax_cumulative_first_dose  \
# month
# April2021        2.708165e+06               2.203361e+06
# August2021       1.161558e+07               8.365202e+06
# ...

# %%
vacc_month_sum=vaccine.groupby(["month"]).sum()
vacc_month_sum
# Out:
#                vax_total_24h  vax_first_dose_24h  vax_sec_dose_24h  \
# month
# April2021             909117              676944            232173
# August2021           3236185             2061578           1174607
# December2021         3609965             1327611           2282354
# January2022           417224              189784            227440
# July2021             2034672             1253647            781025
# June2021             2056714             1551996            504718
# May2021              1929697             1431438            498259
# November2021         2257913              827388           1430543
# October2021          2745042             1049531           1695511
# September2021        4314096             2428186           1885910
#
#                vax_cumulative  vax_cumulative_first_dose  \
# month
# April2021            37914307                   30847052
# August2021          348467535                  250956071
# ...

# %%
vacc_month_sum["Index"]=vacc_month_sum.index.values.copy()
vacc_month_sum["Index"]=vacc_month_sum["Index"].apply(lambda x:set_index(x))
vacc_month_sum.sort_values(["Index"],inplace=True)

# %% [markdown]
# DESCRIPTION: The graph shows the total vaccines registered and total sum of all types of vaccines registered month-wise.
# Here, we can find from October 2021, the number of second dose registered is more than first dose.

# %%
vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='month'>
